# %%
from PIL import Image

# %%
im = Image.open("peacock.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x240>

# %% [markdown]
# # Dải màu hình ảnh

# %%
im.getbands()
# Out:
# ('R', 'G', 'B')

# %% [markdown]
# # Loại và độ sâu của pixel trong ảnh dùng mode

# %%
im.mode
# Out:
# 'RGB'

# %%
im.size
# Out:
# (360, 240)

# %% [markdown]
# # Tạo JPEG thumbnails

# %%
size = 128, 128
im.thumbnail(size)
im.save('thumb.png')
